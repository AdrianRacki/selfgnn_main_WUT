# %%
from config_utils import load_config
cfg = load_config("config")
from dataset import LabeledGraphDataset
import hydra
from torchmetrics import MetricCollection
import torch
from generic import MLP
from module import GraphPredictor

# %%
dataset = hydra.utils.instantiate(cfg.data.dataset)
graph_1 = dataset[0]
graph_2 = dataset[1]
model = hydra.utils.instantiate(cfg.model, _recursive_=False)
module = GraphPredictor(cfg)

# %%
dataloder =hydra.utils.instantiate(cfg.data.datamodule, dataset=dataset)

# %%
dataloder.setup()

# %%
dataloder.train_dataloader()

# %%
# Out:
# DataBatch(x=[670, 8], edge_index=[2, 1288], edge_attr=[1288, 4], smiles=[32], y=[32], batch=[670], ptr=[33])
